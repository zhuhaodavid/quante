# %%
import quante as qt

ham = qt.generate.operas.heisenberg_operator(L=5)
ham.show('xx')
# ham.trotter_gates(order='1', evolve_type=)

# %%
import quante as qt
op = qt.generate.operas
L = 10
ham = op.heisenberg_operator(L=L)
# print(ham.data['yy'][0])
# print(ham.data['yy'][1])
# ham.data['yy'][0][0]
# ham.data['yy'][1][0]
# print(ham.data['yy'][0][0], ham.data['yy'][1][0])
print(ham)
# Out:
# <Oper 0x271359d63d0
#  .data = xx: (0, 1) => 1.0  (1, 2) => 1.0  (2, 3) => 1.0  (3, 4) => 1.0  (4, 5) => 1.0  (5, 6) => 1.0  (6, 7) => 1.0  (7, 8) => 1.0  (8, 9) => 1.0
#          yy: (0, 1) => 1.0  (1, 2) => 1.0  (2, 3) => 1.0  (3, 4) => 1.0  (4, 5) => 1.0  (5, 6) => 1.0  (6, 7) => 1.0  (7, 8) => 1.0  (8, 9) => 1.0
#          zz: (0, 1) => 1.0  (1, 2) => 1.0  (2, 3) => 1.0  (3, 4) => 1.0  (4, 5) => 1.0  (5, 6) => 1.0  (6, 7) => 1.0  (7, 8) => 1.0  (8, 9) => 1.0
#  .type = s
# >

# %%
import quante as qt
import time
op = qt.generate.operas
L = 1000
ham = op.heisenberg_operator(L=L)
t = time.time()
# ham.gate2_decomposition(L=L,tau=0.01)
ham.trotter_gates(L=L,tau=0.01)
# ham.expandxy()
print("Time taken:", time.time()-t)
# Out:
# Time taken: 0.23746657371520996

# %%
import quante as qt
import time
import quante.generate.old_operas as oldop
L = 1000
ham = oldop.heisenberg_operator(L=L)
t = time.time()
# ham.gate2_decomposition(L=L,tau=0.01)
ham.trotter_gates(L=L,tau=0.01)
# ham.expandxy()
print("Time taken:", time.time()-t)
# Out:
# Time taken: 2.425102710723877

# %%
import quante as qt
import numpy as np
import time
op = qt.generate.operas
L = 10
basis = qt.generate.basis.spin_basis(L=L)
ham = op.heisenberg_operator(L=L, h=1)
print(ham)
mat1 = ham.to_matrix(basis)
ham = oldop.heisenberg_operator(L=L, h=1)
mat2 = ham.to_matrix(basis)
print(np.allclose(mat1, mat2))
# Out:
# <Oper 0x267f5ab5d90
#  .data = z: (0,) => 1.0  (1,) => 1.0  (2,) => 1.0  (3,) => 1.0  (4,) => 1.0  (5,) => 1.0  (6,) => 1.0  (7,) => 1.0  (8,) => 1.0  (9,) => 1.0
#          xx: (0, 1) => 1.0  (1, 2) => 1.0  (2, 3) => 1.0  (3, 4) => 1.0  (4, 5) => 1.0  (5, 6) => 1.0  (6, 7) => 1.0  (7, 8) => 1.0  (8, 9) => 1.0
#          yy: (0, 1) => 1.0  (1, 2) => 1.0  (2, 3) => 1.0  (3, 4) => 1.0  (4, 5) => 1.0  (5, 6) => 1.0  (6, 7) => 1.0  (7, 8) => 1.0  (8, 9) => 1.0
#          zz: (0, 1) => 1.0  (1, 2) => 1.0  (2, 3) => 1.0  (3, 4) => 1.0  (4, 5) => 1.0  (5, 6) => 1.0  (6, 7) => 1.0  (7, 8) => 1.0  (8, 9) => 1.0
#  .type = s
# >
# True
