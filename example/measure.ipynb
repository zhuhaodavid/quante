# %%
import quante as qt
import numpy as np

op = qt.generate.operas.spin

L = 14

builder = op.builder()
for i in range(L-1):
    builder += 'xx', [i, i+1], 1.
    builder += 'yy', [i, i+1], 1.
    builder += 'zz', [i, i+1], 1.
    builder += 'z', [i,], 10 * np.random.rand()
ham = builder.build()

basis = qt.generate.basis.spin_basis(L=L, Nup=L//2)
mat = ham.to_matrix(basis=basis)
eng = np.linalg.eigvalsh(mat)
qt.measure.plot_level_spacing_distribution(
    eng, st_dists=['poisson', 'wigner-dyson-1']
)

import matplotlib.pyplot as plt
qt.basicfun.plt_style_use('science')
plt.legend()
plt.xlim(0,4)
# Out:
# (0.0, 4.0)

# %%
import quante as qt
import numpy as np

op = qt.generate.operas.spin

L = 14

builder = op.builder()
for i in range(L-1):
    builder += 'xx', [i, i+1], 1.
    builder += 'yy', [i, i+1], 1.
    builder += 'zz', [i, i+1], 1.
    builder += 'z', [i,], 10 * np.random.rand()
ham = builder.build()

basis = qt.generate.basis.spin_basis(L=L, Nup=L//2)
mat = ham.to_matrix(basis=basis)
eng = np.linalg.svdvals(mat)
qt.measure.mean_level_spacing(eng[::-1])
# Out:
# np.float64(0.3860551707650734)

# %%
import quante as qt
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
data = np.random.normal(size=1000)
hist, bins, mean, std = qt.measure.hist_gaussian(data, ax=ax, plot=False)
qt.measure.plot_hist(hist, bins, ax=ax, linestyle='-')
qt.measure.plot_gaussian(mean, std, ax=ax, linestyle='--')
